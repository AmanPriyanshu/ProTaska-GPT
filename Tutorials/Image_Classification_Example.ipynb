# %%
# !pip install ProTaska-GPT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ProTaska-GPT in /usr/local/lib/python3.10/dist-packages (0.0.12)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (from ProTaska-GPT) (0.0.202)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ProTaska-GPT) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ProTaska-GPT) (1.5.3)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from ProTaska-GPT) (0.4.6)
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.10/dist-packages (from ProTaska-GPT) (1.4.0)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (from ProTaska-GPT) (0.27.8)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from ProTaska-GPT) (2.13.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from ProTaska-GPT) (0.4.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (0.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (0.15.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->ProTaska-GPT) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->ProTaska-GPT) (2.0.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->ProTaska-GPT) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain->ProTaska-GPT) (0.5.8)
# Requirement already satisfied: langchainplus-sdk>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from langchain->ProTaska-GPT) (0.0.10)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain->ProTaska-GPT) (2.8.4)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /usr/local/lib/python3.10/dist-packages (from langchain->ProTaska-GPT) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain->ProTaska-GPT) (1.10.7)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->ProTaska-GPT) (8.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ProTaska-GPT) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ProTaska-GPT) (2022.7.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->ProTaska-GPT) (2022.10.31)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia->ProTaska-GPT) (4.11.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ProTaska-GPT) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ProTaska-GPT) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ProTaska-GPT) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ProTaska-GPT) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ProTaska-GPT) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ProTaska-GPT) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain->ProTaska-GPT) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain->ProTaska-GPT) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain->ProTaska-GPT) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets->ProTaska-GPT) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets->ProTaska-GPT) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->ProTaska-GPT) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->ProTaska-GPT) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->ProTaska-GPT) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->ProTaska-GPT) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->ProTaska-GPT) (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia->ProTaska-GPT) (2.4.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain->ProTaska-GPT) (1.0.0)

# %%
from protaska.describer import describe_dataset
from protaska.ideate import main as chatbot

# %%
openai_key = 'Enter **secret key**'
importer_type = "HuggingFaceDatasetImporter"
dataset_key = 'mnist'
destination_path = './downloaded_data/'

# %%
description, dataloader_obj = describe_dataset(openai_key, importer_type, destination_path, dataset_key)
description
# Out:
# Downloading builder script:   0%|          | 0.00/3.98k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.21k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/6.83k [00:00<?, ?B/s]
# Downloading and preparing dataset mnist/mnist to /root/.cache/huggingface/datasets/mnist/mnist/1.0.0/9d494b7f466d6931c64fb39d58bb1249a4d85c9eb9865d9bc20960b999e2a332...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/9.91M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/28.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.54k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset mnist downloaded and prepared to /root/.cache/huggingface/datasets/mnist/mnist/1.0.0/9d494b7f466d6931c64fb39d58bb1249a4d85c9eb9865d9bc20960b999e2a332. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# Saving the dataset (0/1 shards):   0%|          | 0/60000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# 'Description: The dataset is MNIST from HuggingFace, consisting of images of handwritten digits and their corresponding labels. The dataset is split into a training and testing set, with 60,000 and 10,000 rows respectively. The task for this dataset is classification, specifically recognizing the digit in the image. The data type is image and the field/topic is digit recognition.'

# %%
chatbot(openai_key, description, dataloader_obj.superficial_meta_data, agent_verbose=False)
# Out:
# ProTaska:	 Hello! As a Data Science and Machine Learning expert, I can help you explore opportunities for data-science with the MNIST dataset from HuggingFace. Here are some tasks you can perform:
#
# 1. Image Classification: The task for this dataset is classification, specifically recognizing the digit in the image. You can use machine learning algorithms such as Support Vector Machines (SVM), Random Forest, or Neural Networks to classify the images. You can use libraries such as scikit-learn, TensorFlow, or PyTorch to implement these algorithms. To install scikit-learn, you can use the command "pip install scikit-learn".
#
# 2. Data Visualization: You can visualize the images in the dataset to get a better understanding of the data. You can use libraries such as Matplotlib or Seaborn to create visualizations. To install Matplotlib, you can use the command "pip install matplotlib".
#
# 3. Data Preprocessing: You can preprocess the images in the dataset to improve the performance of your machine learning models. You can use techniques such as normalization, resizing, or data augmentation. You can use libraries such as OpenCV or Pillow to implement these techniques. To install OpenCV, you can use the command "pip install opencv-python".
#
# Do you have any questions or would you like me to explain anything in more detail?
# ProTaska-Source:	 Connected to Wikipedia for external information!
#
# Human (input 'break' or 'exit' to stop the loop):	exit
# ProTaska:	Stopping Execution!
